# %% [markdown]
# (1) **make_withdrawal(self, amount)** - have this method decrease the user's balance by the amount specified

# %%
class User:
    def __init__(self, username, email_address):
        self.name = username
        self.email = email_address
        self.account_balance = 0
    def deposit(self, ammount):
        self.account_balance += ammount
    def withdrawal(self, ammount):
        self.account_balance -= ammount

guido = User("Guido van Rossum", "guido@python.com")
monty = User("Monty Python", "monty@python.com")

# %%
guido.withdrawal(150)
guido.deposit(600)

print(guido.account_balance)
# Out:
# 450

# %% [markdown]
# (2) **display_user_balance(self)** - have this method print the user's name and account balance to the terminal
# >eg. "User: Guido van Rossum, Balance: $150

# %%
class User:
    def __init__(self, username, email_address):
        self.name = username
        self.email = email_address
        self.account_balance = 0
    def deposit(self, ammount):
        self.account_balance += ammount
    def withdrawal(self, ammount):
        self.account_balance -= ammount
    def balance(self):
        print(f"User: {self.name}, Balance: {self.account_balance}")

guido = User("Guido van Rossum", "guido@python.com")

guido.deposit(200)
guido.withdrawal(50)
guido.balance()
# Out:
# User: Guido van Rossum, Balance: 150

# %% [markdown]
# (3) **BONUS: transfer_money(self, other_user, amount)** - have this method decrease the user's balance by the amount and add that amount to other other_user's balance

# %%
class User:
    def __init__(self, username, email_address):
        self.name = username
        self.email = email_address
        self.account_balance = 0
    def deposit(self, ammount):
        self.account_balance += ammount
    def withdrawal(self, ammount):
        self.account_balance -= ammount
    def balance(self):
        print(f"User: {self.name}, Balance: {self.account_balance}")
    def transfer(self, ammount, rec_name):
        #if (rec_name == rec_name.name):
            self.account_balance -= ammount
            rec_name.account_balance += ammount
        #else:
            #print("account name invalid")
    def __get__(self, )

guido = User("Guido van Rossum", "guido@python.com")
monty = User("Monty Python", "monty@python.com")

guido.deposit(200)
guido.transfer(100, monty)
guido.balance()
monty.balance()
# Out:
# User: Guido van Rossum, Balance: 100
# User: Monty Python, Balance: 100
