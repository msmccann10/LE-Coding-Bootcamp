# %% [markdown]
# # Mapping Yelp Search Results - Part 1

# %% [markdown]
# - 04/26/22

# %% [markdown]
# ## Obective

# %% [markdown]
# - For this CodeAlong, we will be working with the Yelp API.
# - You will use the the Yelp API to search your home town for a cuisine type of your choice.
# - Next class, we will then use Plotly Express to create a map with the Mapbox API to visualize the results.

# %% [markdown]
# ## Tools You Will Use
# - Part 1:
#     - Yelp API:
#         - Getting Started:
#             - https://www.yelp.com/developers/documentation/v3/get_started
#
#     - `YelpAPI` python package
#         -  "YelpAPI": https://github.com/gfairchild/yelpapi
# - Part 2:
#
#     - Plotly Express: https://plotly.com/python/getting-started/
#         - With Mapbox API: https://www.mapbox.com/
#         - `px.scatter_mapbox` [Documentation](https://plotly.com/python/scattermapbox/):

# %% [markdown]
# ### Applying Code From
# - Efficient API Calls Lesson Link: https://login.codingdojo.com/m/376/12529/88078

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# ## 1. Registering for Required APIs

# %% [markdown]
# - Yelp: https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# > Check the official API documentation to know what arguments we can search for: https://www.yelp.com/developers/documentation/v3/business_search

# %% [markdown]
# ### Load Credentials and Create Yelp API Object

# %%
# Load API Credentials
key_path = '../../.secret/yelp_api.json'
with open(key_path, 'r') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'], timeout_s=3)
yelp

# %% [markdown]
# ### Define Search Terms and File Paths

# %%
# set our API call parameters and filename before the first call
LOCATION = "Charlottesville, VA"
TERM = "Brewery"

# %%
## Specify fodler for saving data
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)

# %%
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = f"{FOLDER}{TERM}{LOCATION.split(',')[0]}.json"
JSON_FILE
# Out:
# 'Data/BreweryCharlottesville.json'

# %% [markdown]
# ### Check if Json File exists and Create it if it doesn't

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
                
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    with open(JSON_FILE, 'w') as f:
        json.dump([],f)
    
    ## save the first page of results

        
## If it exists, inform user
else: print(f"[i] {JSON_FILE} already exists")
# Out:
# [i] Data/BreweryCharlottesville.json already exists

# %% [markdown]
# ### Load JSON FIle and account for previous results

# %%
## Load previous results and use len of results for offset
with open(JSON_FILE, 'r') as f:
    previous_results = json.load(f)
    
## set offset based on previous results
n_results = len(previous_results)
print(f' - {n_results} previous results found.')
# Out:
#  - 55 previous results found.

# %% [markdown]
# ### Make the first API call to get the first page of data

# %% [markdown]
# - We will use this first result to check:
#     - how many total results there are?
#     - Where is the actual data we want to save?
#     - how many results do we get at a time?

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = TERM, location = LOCATION)
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
## How many results total?
results['total']
# Out:
# 76

# %% [markdown]
# - Where is the actual data we want to save?

# %%
type(results['businesses'])
# Out:
# list

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %% [markdown]
# - Calculate how many pages of results needed to cover the total_results

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil(results['total']/results_per_page)
n_pages
# Out:
# 4

# %%
for i in tqdm_notebook( range(0,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        time.sleep(.2)        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)

        ## set offset based on previous results
        n_results = len(previous_results)
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(term=TERM,
                                   location=LOCATION,
                                   offset=n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open (JSON_FILE, 'w') as f:
            json.dump(previous_results, f)
            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(e)
        break
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# ## Open the Final JSON File with Pandas

# %%
df = pd.read_json(JSON_FILE)
df
# Out:
#                         id                                              alias  \
# 0   mr7C4suIQWIU35BL1SgZCA                 random-row-brewing-charlottesville
# 1   asAthOuraDc_NxBY6Ne9lA               south-street-brewery-charlottesville
# 2   lFnfvVdrkr5ZCNAiqt-Tpg                 starr-hill-brewery-charlottesville
# 3   1263xqcmsqqUURfrp427HQ                 selvedge-brewing-charlottesville-2
# 4   VnCEHYb3tHaLYdLRIqHcDQ  three-notchd-craft-kitchen-and-brewery-charlot...
# 42  RWy9KbL58h9HhTfJOHhmJA                        vingo-tours-charlottesville
# 43  jmay81hcvvaE7sUTos4SsQ    mellow-mushroom-charlottesville-charlottesville
# 44  MFWjgsK8wOwiUlSJwhdHhg               market-street-wine-charlottesville-2
# 45  wVLkhB8ijpUoDRlTejbcNg                          the-local-charlottesville
# 46  5qNkM1pPktyaQVbQfjZfdw           top-shelf-transportation-charlottesville
# 47  yQ27NzO_Odi1gsjdv-XpfQ     charlottesville-transportation-charlottesville
# 48  z7yxxO75Jm7GnXlvm3VzyQ                     wine-warehouse-charlottesville
# 49  NnI21y2FU2RQKOWBAWDCzA             wine-tours-of-virginia-charlottesville
# 50  Ao_d_F2Hb5sAKA2QR9dt8Q  monticello-appellation-wine-tours-charlottesvi...
# 51  F7xWtecL4tBV41D2Ykh3aA      hamiltons-at-first-and-main-charlottesville-2
# 52  taw2SaANYLc2aHEX8aOehQ            wegmans-wine-and-beer-charlottesville-2
# 53  LZbSe-peqgynuLoUaCI5Wg                 wineworks-extended-charlottesville
# 54  t5ZTKNJggq-U0vt9Qk41Wg         blue-ridge-wine-excursions-charlottesville
#
#                                      name  \
# 0                      Random Row Brewing
# 1                    South Street Brewery
# 2                      Starr Hill Brewery
# 3                        Selvedge Brewing
# 4   Three Notch'd Craft Kitchen & Brewery
# 5                        Champion Brewing
# 6                             Reason Beer
# 7                Rockfish Brewing Company
# 8                           Kardinal Hall
# 9             North American Sake Brewery
# 10                   Potter's Craft Cider
# 11                Glass Half Full Taproom
# 12                        The Whiskey Jar
# 13                    Cville Hop On Tours
# 14                        Sedona Taphouse
# 15            Meriwether Springs Vineyard
# 16                      Castle Hill Cider
# 17              Oakhart Social Restaurant
# 18                           Trump Winery
# 19                               Beer Run
# 20       Jack Brown's Beer & Burger Joint
# 21                    Jefferson Vineyards
# 22   Lazy Parrot Backyard Wings and Brews
# 23                     LW's Livery Stable
# 24                     Citizen Burger Bar
# 25                                Firefly
# 26                                  Lampo
# 27                   Wish Wish Wine Tours
# 28                            IX Art Park
# 29           Taste of Virginia Food Tours
# 30                     Glass House Winery
# 31                                  Tonic
# 32                   Timberwood Tap House
# 33               Dürty Nelly's Pub - Deli
# 34            BJ's Restaurant & Brewhouse
# 35                Carter Mountain Orchard
# 36                    Grace Estate Winery
# 37                Orzo Kitchen & Wine Bar
# 38                Michael Shaps Wineworks
# 39                         Champion Grill
# 40                                Rapture
# 41        Norm’s Executive Transportation
# 42                            VinGo Tours
# 43      Mellow Mushroom - Charlottesville
# 44                     Market Street Wine
# 45                              The Local
# 46               Top Shelf Transportation
# 47         Charlottesville Transportation
# 48                         Wine Warehouse
# 49                 Wine Tours of Virginia
# 50      Monticello Appellation Wine Tours
# 51           Hamiltons' At First and Main
# 52                    Wegmans Wine & Beer
# 53                     Wineworks Extended
# 54             Blue Ridge Wine Excursions
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/FUkM4k...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/QUbgUs...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/UOJDRu...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/Gy9bmy...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/T01te9...      False
# 5   https://s3-media4.fl.yelpcdn.com/bphoto/M-xuHZ...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/2MJVa0...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/K0ubdo...      False
# 8   https://s3-media4.fl.yelpcdn.com/bphoto/N-PJMO...      False
# 9   https://s3-media1.fl.yelpcdn.com/bphoto/aC9myA...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/z1nLq0...      False
# 11  https://s3-media4.fl.yelpcdn.com/bphoto/1lzn-6...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto
# 7   [{'alias': 'breweries', 'title': 'Breweries'},...     4.0
# 8   [{'alias': 'beergardens', 'title': 'Beer Garde...     4.0
# 9   [{'alias': 'breweries', 'title': 'Breweries'},...     4.0
# 10       [{'alias': 'cideries', 'title': 'Cideries'}]     4.5
# 11               [{'alias': 'pubs', 'title': 'Pubs'}]     5.0
# 12  [{'alias': 'southern', 'title': 'Southern'}, {...     3.5
# 13  [{'alias': 'bustours', 'title': 'Bus Tours'}, ...     5.0
# 14  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 15  [{'alias': 'venues', 'title': 'Venues & Event ...     4.5
# 16       [{'alias': 'cideries', 'title': 'Cideries'}]     4.0
# 17  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 18       [{'alias': 'wineries', 'title': 'Wineries'}]     4.0
# 19  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 20  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 21       [{'alias': 'wineries', 'title': 'Wineries'}]     4.0
# 22       [{'alias': 'brewpubs', 'title': 'Brewpubs'}]     3.5
# 23  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 24  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 25  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 26  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 27    [{'alias': 'winetours', 'title': 'Wine Tours'}]     5.0
# 28  [{'alias': 'theater', 'title': 'Performing Art...     4.5
# 29    [{'alias': 'foodtours', 'title': 'Food Tours'}]     5.0
# 30  [{'alias': 'wineries', 'title': 'Wineries'}, {...     4.5
# 31  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 32  [{'alias': 'tradamerican', 'title': 'American ...     3.5
# 33  [{'alias': 'delis', 'title': 'Delis'}, {'alias...     4.0
# 34  [{'alias': 'breweries', 'title': 'Breweries'},...     2.5
# 35  [{'alias': 'pickyourown', 'title': 'Pick Your ...     4.0
# 36  [{'alias': 'wineries', 'title': 'Wineries'}, {...     4.0
# 37  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...     4.0
# 38       [{'alias': 'wineries', 'title': 'Wineries'}]     4.0
# 39       [{'alias': 'brewpubs', 'title': 'Brewpubs'}]     3.0
# 40  [{'alias': 'newamerican', 'title': 'American (...     3.5
# 41  [{'alias': 'winetours', 'title': 'Wine Tours'}...     5.0
# 42    [{'alias': 'winetours', 'title': 'Wine Tours'}]     5.0
# 43  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 44  [{'alias': 'beer_and_wine', 'title': 'Beer, Wi...     4.5
# 45  [{'alias': 'newamerican', 'title': 'American (...     3.5
# 46  [{'alias': 'winetours', 'title': 'Wine Tours'}...     5.0
# 47  [{'alias': 'airport_shuttles', 'title': 'Airpo...     5.0
# 48  [{'alias': 'beer_and_wine', 'title': 'Beer, Wi...     4.0
# 49    [{'alias': 'winetours', 'title': 'Wine Tours'}]     1.0
# 50    [{'alias': 'winetours', 'title': 'Wine Tours'}]     5.0
# 51  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 52  [{'alias': 'beer_and_wine', 'title': 'Beer, Wi...     5.0
# 53  [{'alias': 'winetastingroom', 'title': 'Wine T...     3.5
# 54             [{'alias': 'tours', 'title': 'Tours'}]     4.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 38.0350243, 'longitude': -78.4864...                  []
# 1   {'latitude': 38.029338, 'longitude': -78.4826883}          [delivery]
# 2   {'latitude': 38.03777667, 'longitude': -78.491...                  []
# 3   {'latitude': 38.01952965628474, 'longitude': -...                  []
# 4   {'latitude': 38.0261135531783, 'longitude': -7...          [delivery]
# 5   {'latitude': 38.0277683, 'longitude': -78.4784...                  []
# 6   {'latitude': 38.0703773245881, 'longitude': -7...                  []
# 7    {'latitude': 38.037279, 'longitude': -78.489467}                  []
# 8   {'latitude': 38.03621156211071, 'longitude': -...          [delivery]
# 9   {'latitude': 38.0259306513344, 'longitude': -7...            [pickup]
# 10     {'latitude': 38.02725, 'longitude': -78.47682}                  []
# 11  {'latitude': 38.0103853, 'longitude': -78.5001...                  []
# 12  {'latitude': 38.0314077544935, 'longitude': -7...  [pickup, delivery]
# 13   {'latitude': 38.026127, 'longitude': -78.482209}                  []
# 14   {'latitude': 38.051092, 'longitude': -78.505657}                  []
# 15     {'latitude': 38.06736, 'longitude': -78.59546}                  []
# 16  {'latitude': 38.0869674682617, 'longitude': -7...                  []
# 17  {'latitude': 38.0310519381534, 'longitude': -7...          [delivery]
# 18      {'latitude': 37.94642, 'longitude': -78.5051}                  []
# 19    {'latitude': 38.024637, 'longitude': -78.46844}          [delivery]
# 20     {'latitude': 38.03019, 'longitude': -78.48109}  [delivery, pickup]
# 21   {'latitude': 37.990044, 'longitude': -78.443643}                  []
# 22   {'latitude': 38.056523, 'longitude': -78.495851}                  []
# 23  {'latitude': 38.0316076774443, 'longitude': -7...          [delivery]
# 24  {'latitude': 38.0304396046825, 'longitude': -7...          [delivery]
# 25  {'latitude': 38.0255814, 'longitude': -78.4671...  [delivery, pickup]
# 26   {'latitude': 38.0273899, 'longitude': -78.47684}          [delivery]
# 27  {'latitude': 38.0110704, 'longitude': -78.4983...                  []
# 28  {'latitude': 38.0261880044002, 'longitude': -7...                  []
# 29  {'latitude': 38.02940667, 'longitude': -78.477...                  []
# 30  {'latitude': 38.2025939, 'longitude': -78.5791...                  []
# 31     {'latitude': 38.03055, 'longitude': -78.47695}          [delivery]
# 32  {'latitude': 38.0101951, 'longitude': -78.4989...  [delivery, pickup]
# 33   {'latitude': 38.025687, 'longitude': -78.515404}  [delivery, pickup]
# 34  {'latitude': 38.06729410372431, 'longitude': -...          [delivery]
# 35      {'latitude': 37.9896, 'longitude': -78.47364}                  []
# 36     {'latitude': 38.11525, 'longitude': -78.68259}                  []
# 37    {'latitude': 38.030408, 'longitude': -78.48726}          [delivery]
# 38     {'latitude': 37.89818, 'longitude': -78.55736}                  []
# 39   {'latitude': 38.065649, 'longitude': -78.493329}                  []
# 40  {'latitude': 38.0303673, 'longitude': -78.4796...          [delivery]
# 41  {'latitude': 38.01734924316406, 'longitude': -...                  []
# 42  {'latitude': 38.0423698425293, 'longitude': -7...                  []
# 43  {'latitude': 38.03371582970856, 'longitude': -...          [delivery]
# 44  {'latitude': 38.0310371, 'longitude': -78.4790...                  []
# 45     {'latitude': 38.02446, 'longitude': -78.47555}          [delivery]
# 46   {'latitude': 38.086855, 'longitude': -78.469888}                  []
# 47  {'latitude': 38.0423698425293, 'longitude': -7...                  []
# 48  {'latitude': 38.0607741, 'longitude': -78.4914...                  []
# 49  {'latitude': 38.1078147888184, 'longitude': -7...                  []
# 50  {'latitude': 37.9990877, 'longitude': -78.422138}                  []
# 51  {'latitude': 38.0308619141579, 'longitude': -7...  [delivery, pickup]
# 52     {'latitude': 38.00997, 'longitude': -78.49927}                  []
# 53    {'latitude': 38.00821, 'longitude': -78.491042}                  []
# 54      {'latitude': 38.03563, 'longitude': -78.4948}                  []
#
#    price                                           location        phone  \
# 0      $  {'address1': '608 Preston Ave', 'address2': ''...  14342848466
# 1     $$  {'address1': '106 W South St', 'address2': '',...  14342936550
# 2    NaN  {'address1': '946 Grady Ave', 'address2': None...  14348235671
# 3    NaN  {'address1': '1837 Broadway St', 'address2': '...  14342700555
# 4     $$  {'address1': '520 2nd St SE', 'address2': None...  14349563141
# 5     $$  {'address1': '324 6th St SE', 'address2': '', ...  14342952739
# 6     $$  {'address1': '1180 Seminole Trl', 'address2': ...  14342600145
# 7    NaN  {'address1': '900 Preston Ave', 'address2': ''...  14345660969
# 8     $$  {'address1': '722 Preston Ave', 'address2': 'S...  14342954255
# 9     $$  {'address1': '522 2nd St SE', 'address2': '', ...  14347678105
# 10   NaN  {'address1': '209 Monticello Rd', 'address2': ...  14349640271
# 11   NaN  {'address1': '375 Merchant Walk Dr', 'address2...  14343265056
# 12    $$  {'address1': '227 W Main St', 'address2': '', ...  14342021549
# 13     $  {'address1': '1591 Delphi Ln', 'address2': '',...  14342183565
# 14    $$  {'address1': '1035 Millmont St', 'address2': '...  14342962337
# 15    $$  {'address1': '1040 Owensville Rd', 'address2':...  14349647955
# 16    $$  {'address1': '6065 Turkey Sag Rd', 'address2':...  14342960047
# 17    $$  {'address1': '511 W Main St', 'address2': '', ...  14349955449
# 18    $$  {'address1': '385 Albemarle House Dr', 'addres...  14342669909
# 19    $$  {'address1': '156 Carlton Rd', 'address2': 'St...  14349842337
# 20     $  {'address1': '109 2nd St SE', 'address2': None...  14342440073
# 21    $$  {'address1': '1353 Thomas Jefferson Pkwy', 'ad...  14349773042
# 22    $$  {'address1': '594 Pantops Ctr', 'address2': ''...  14342440723
# 23    $$  {'address1': '120 Old Preston Ave', 'address2'...  14349955674
# 24    $$  {'address1': '212 E Main St', 'address2': '', ...  14349799944
# 25    $$  {'address1': '1304 E Market St', 'address2': N...  14342021050
# 26    $$  {'address1': '205 Monticello Rd', 'address2': ...  14342443226
# 27   NaN  {'address1': '435 Merchant Walk Sq', 'address2...  14342021615
# 28   NaN  {'address1': '522 2nd St SE', 'address2': None...  14342072355
# 29   NaN  {'address1': '610 E Main St', 'address2': None...  14345895558
# 30    $$  {'address1': '5898 Free Union Rd', 'address2':...  14349750094
# 31   NaN  {'address1': '609 E Market St', 'address2': No...  14342264270
# 32    $$  {'address1': '245 Merchant Walk Ave', 'address...  14342343563
# 33     $  {'address1': '2200 Jefferson Park Ave', 'addre...  14342951278
# 34    $$  {'address1': '3924 Lenox Ave', 'address2': '',...  14344225170
# 35     $  {'address1': '1435 Carters Mountain Trl', 'add...  14349771833
# 36    $$  {'address1': '5275 Mount Juliet Farm', 'addres...  14348231486
# 37    $$  {'address1': '416 W Main St', 'address2': '', ...  14349756796
# 38    $$  {'address1': '1781 Harris Creek Way', 'address...  14342963438
# 39   NaN  {'address1': '2075 Bond St', 'address2': 'Ste ...  14342021076
# 40    $$  {'address1': '303 E Main St', 'address2': '', ...  14342939526
# 41   NaN  {'address1': '', 'address2': '', 'address3': '...  14349898905
# 42   NaN  {'address1': None, 'address2': None, 'address3...  14342601603
# 43    $$  {'address1': '1321 W Main St', 'address2': '',...  14349729366
# 44    $$  {'address1': '311 E Market St', 'address2': ''...  14342020511
# 45    $$  {'address1': '824 Hinton Ave', 'address2': '',...  14349849749
# 46   NaN  {'address1': '1869 Seminole Trl', 'address2': ...  14342959462
# 47   NaN  {'address1': None, 'address2': None, 'address3...  14344668465
# 48    $$  {'address1': '1804 Hydraulic Rd', 'address2': ...  14342961727
# 49   NaN  {'address1': '2591 Pea Ridge Rd', 'address2': ...  14348232380
# 50   NaN  {'address1': '1493 Milton Rd', 'address2': '',...  18888247273
# 51    $$  {'address1': '101 W Main St', 'address2': '', ...  14342956649
# 52   NaN  {'address1': '100 Wegmans Way', 'address2': No...  14345293285
# 53   NaN  {'address1': '1585 Avon Street Ext', 'address2...  14345296848
# 54   NaN  {'address1': '', 'address2': None, 'address3':...  14345315802
#
#      display_phone      distance
# 0   (434) 284-8466   1312.456426
# 1   (434) 293-6550   1766.043547
# 2   (434) 823-5671   1392.568242
# 3   (434) 270-0555   3425.095608
# 4   (434) 956-3141   2108.785792
# 5   (434) 295-2739   1894.850786
# 6   (434) 260-0145   2985.209247
# 7   (434) 566-0969   1301.019922
# 8   (434) 295-4255   1283.554013
# 9   (434) 767-8105   2127.053892
# 10  (434) 964-0271   1956.231775
# 11  (434) 326-5056   4099.448111
# 12  (434) 202-1549   1543.354435
# 13  (434) 218-3565   2107.654928
# 14  (434) 296-2337   2513.344418
# 15  (434) 964-7955  10236.237589
# 16  (434) 296-0047  17104.183846
# 17  (434) 995-5449   1740.927957
# 18  (434) 266-9909  11233.849476
# 19  (434) 984-2337   2396.153942
# 20  (434) 244-0073   1646.013829
# 21  (434) 977-3042   6630.950399
# 22  (434) 244-0723   2029.230977
# 23  (434) 995-5674   1530.648680
# 24  (434) 979-9944   1621.733144
# 25  (434) 202-1050   2323.924763
# 26  (434) 244-3226   1941.221876
# 27  (434) 202-1615   4150.116150
# 28  (434) 207-2355   2102.660717
# 29  (434) 589-5558   1736.836027
# 30  (434) 975-0094  19646.202482
# 31  (434) 226-4270   1594.403086
# 32  (434) 234-3563   4261.025390
# 33  (434) 295-1278   3898.485202
# 34  (434) 422-5170   2647.345932
# 35  (434) 977-1833   5967.364459
# 36  (434) 823-1486  19538.481140
# 37  (434) 975-6796   1790.186265
# 38  (434) 296-3438  17707.201611
# 39  (434) 202-1076   2674.755451
# 40  (434) 293-9526   1609.849625
# 41  (434) 989-8905   1727.472447
# 42  (434) 260-1603   1727.472447
# 43  (434) 972-9366   2179.481160
# 44  (434) 202-0511   1527.880171
# 45  (434) 984-9749   2272.332551
# 46  (434) 295-9462   4728.832738
# 47  (434) 466-8465   1727.472447
# 48  (434) 296-1727   2126.272821
# 49  (434) 823-2380  15928.429070
# 50  (888) 824-7273   7084.393668
# 51  (434) 295-6649   1572.111967
# 52  (434) 529-3285   4466.111060
# 53  (434) 529-6848   4224.043801
# 54  (434) 531-5802   1727.472447

# %%
df.duplicated(subset='id').sum()
# Out:
# 0

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/BreweryCharlottesville.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression='gzip', index = False)

# %% [markdown]
# ## Bonus: compare filesize with os module's `os.path.getsize`

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(csv_file)

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz:.2f} times smaller!')
# Out:
# JSON FILE: 54,974 Bytes
# CSV.GZ FILE: 8,537 Bytes
# the csv.gz is 6.44 times smaller!

# %% [markdown]
# ## Next Class: Processing the Results and Mapping
