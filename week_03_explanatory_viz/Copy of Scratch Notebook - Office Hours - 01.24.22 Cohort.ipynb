# %% [markdown]
# # Scratch Notebook for Office Hours

# %%
# !pip install -U cdds
from cdds.imports import *
# Out:
# cdds v0.1.2 loaded.
# <style type="text/css">
# #T_4aa49_row0_col0, #T_4aa49_row0_col2, #T_4aa49_row0_col3, #T_4aa49_row1_col0, #T_4aa49_row1_col2, #T_4aa49_row1_col3, #T_4aa49_row2_col0, #T_4aa49_row2_col2, #T_4aa49_row2_col3, #T_4aa49_row3_col0, #T_4aa49_row3_col2, #T_4aa49_row3_col3, #T_4aa49_row4_col0, #T_4aa49_row4_col2, #T_4aa49_row4_col3, #T_4aa49_row5_col0, #T_4aa49_row5_col2, #T_4aa49_row5_col3, #T_4aa49_row6_col0, #T_4aa49_row6_col2, #T_4aa49_row6_col3, #T_4aa49_row7_col0, #T_4aa49_row7_col2, #T_4aa49_row7_col3 {
#   text-align: left;
# }
# #T_4aa49_row0_col1, #T_4aa49_row0_col4, #T_4aa49_row1_col1, #T_4aa49_row1_col4, #T_4aa49_row2_col1, #T_4aa49_row2_col4, #T_4aa49_row3_col1, #T_4aa49_row3_col4, #T_4aa49_row4_col1, #T_4aa49_row4_col4, #T_4aa49_row5_col1, #T_4aa49_row5_col4, #T_4aa49_row6_col1, #T_4aa49_row6_col4, #T_4aa49_row7_col1, #T_4aa49_row7_col4 {
#   text-align: left;
#   text-align: center;
# }
# </style>
# <table id="T_4aa49_" class="dataframe">
# ...

# %%
df = ds.datasets.load_king_county_housing()
df
# Out:
#                id        date     price  ...     long  sqft_living15  sqft_lot15
# 0      7129300520  10/13/2014  221900.0  ... -122.257           1340        5650
# 1      6414100192   12/9/2014  538000.0  ... -122.319           1690        7639
# 2      5631500400   2/25/2015  180000.0  ... -122.233           2720        8062
# 3      2487200875   12/9/2014  604000.0  ... -122.393           1360        5000
# 4      1954400510   2/18/2015  510000.0  ... -122.045           1800        7503
# ...           ...         ...       ...  ...      ...            ...         ...
# 21592   263000018   5/21/2014  360000.0  ... -122.346           1530        1509
# 21593  6600060120   2/23/2015  400000.0  ... -122.362           1830        7200
# 21594  1523300141   6/23/2014  402101.0  ... -122.299           1020        2007
# 21595   291310100   1/16/2015  400000.0  ... -122.069           1410        1287
# 21596  1523300157  10/15/2014  325000.0  ... -122.299           1020        1357
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df['waterfront'] = df['waterfront'].astype(str)

# %%
import plotly.express as px
fig = px.scatter_3d(df,x='sqft_living',y='sqft_lot',z='bathrooms',color='waterfront')
fig.update_traces(marker=dict(size=2))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from ipywidgets import interact

cols = df.columns

@interact(x=cols,y=cols,z=cols,)
def show_plot(x='sqft_living',y='sqft_lot',z='price',color='waterfront',nrows=500):
    fig = px.scatter_3d(df.sample(nrows),x=x,y=y,z=z,color=color)b
    fig.update_traces(marker=dict(size=2))
    fig.show()

# show_plot()
# Out:
# interactive(children=(Dropdown(description='x', index=5, options=('id', 'date', 'price', 'bedrooms', 'bathroom…

# %%
df
# Out:
#                id        date     price  ...     long  sqft_living15  sqft_lot15
# 0      7129300520  10/13/2014  221900.0  ... -122.257           1340        5650
# 1      6414100192   12/9/2014  538000.0  ... -122.319           1690        7639
# 2      5631500400   2/25/2015  180000.0  ... -122.233           2720        8062
# 3      2487200875   12/9/2014  604000.0  ... -122.393           1360        5000
# 4      1954400510   2/18/2015  510000.0  ... -122.045           1800        7503
# ...           ...         ...       ...  ...      ...            ...         ...
# 21592   263000018   5/21/2014  360000.0  ... -122.346           1530        1509
# 21593  6600060120   2/23/2015  400000.0  ... -122.362           1830        7200
# 21594  1523300141   6/23/2014  402101.0  ... -122.299           1020        2007
# 21595   291310100   1/16/2015  400000.0  ... -122.069           1410        1287
# 21596  1523300157  10/15/2014  325000.0  ... -122.299           1020        1357
#
# ...

# %%
'open-street-map', 'white-bg', 'carto-positron', 'carto-darkmatter', 'stamen- terrain', 'stamen-toner', 'stamen-watercolor'

# %%
px.scatter_mapbox(df,lat='lat',lon='long',mapbox_style='open-street-map',color='price',)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter_geo(df,lat='lat',lon='long',color='price',
                  symbol='waterfront')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Cats Dogs Boxplot

# %%
df = pd.read_excel('https://docs.google.com/spreadsheets/d/e/2PACX-1vTXqVI5_p-kjmdG6Ww9mxHJfB_rM3VlLIbIk6HGCWgy1b0Fy3i9AscZm2JHU9re5Q/pub?output=xlsx')
df
# Out:
#                 Location  ...  Cat Population
# 0                Alabama  ...          1252.0
# 1                Arizona  ...          1438.0
# 2               Arkansas  ...           810.0
# 3             California  ...          7118.0
# 4               Colorado  ...          1191.0
# 5            Connecticut  ...           796.0
# 6               Delaware  ...           187.0
# 7   District of Columbia  ...            63.0
# 8                Florida  ...          4375.0
# 9                Georgia  ...          2162.0
# 10                 Idaho  ...           393.0
# 11              Illinois  ...          2453.0
# 12               Indiana  ...          1912.0
# 13                  Iowa  ...           805.0
# 14                Kansas  ...           731.0
# 15              Kentucky  ...          1349.0
# 16             Louisiana  ...           877.0
# 17                 Maine  ...           498.0
# 18              Maryland  ...          1677.0
# ...

# %%
plot_df = pd.melt(df, id_vars=['Location'],
                  value_vars= ['Mean Number of Cats','Mean Number of Dogs per household'],var_name='Pet Type',
                  value_name='Mean Number per household')
plot_df
# Out:
#          Location                           Pet Type  Mean Number per household
# 0         Alabama                Mean Number of Cats                        2.5
# 1         Arizona                Mean Number of Cats                        1.9
# 2        Arkansas                Mean Number of Cats                        2.3
# 3      California                Mean Number of Cats                        1.9
# 4        Colorado                Mean Number of Cats                        1.9
# ..            ...                                ...                        ...
# 93       Virginia  Mean Number of Dogs per household                        1.6
# 94     Washington  Mean Number of Dogs per household                        1.7
# 95  West Virginia  Mean Number of Dogs per household                        1.8
# 96      Wisconsin  Mean Number of Dogs per household                        1.4
# 97        Wyoming  Mean Number of Dogs per household                        1.5
#
# ...

# %%
ax = sns.boxplot(data=plot_df, x='Pet Type', y='Mean Number per household',notch=True)
ax.set_xticklabels(['Cats','Dogs'])
# Out:
# [Text(0, 0, 'Cats'), Text(0, 0, 'Dogs')]

# %%
rename_map = {"Mean Number of Cats":"Cats","Mean Number of Dogs per household":"Dogs"}
plot_df['Pet'] = plot_df['Pet Type'].replace(rename_map)

# %%
sns.boxplot(data=plot_df, x='Pet', y='Mean Number per household',notch=True,
            medianprops=dict(color='yellow'))

# %% [markdown]
# ## Sales Prediction data

# %% [markdown]
# - Preparing data to visualization correlations with categorical features (student question)

# %%
## project 1
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSsu3nnH_Ppm4Ao9XUqVlUZPfTx8bGv5gNbfSavqMhPhIWp4NwaEZk3W8FgDEhEJbg12sRU_FG5EBAb/pub?output=csv')
df
# Out:
#      Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0              FDA15        9.300  ...  Supermarket Type1          3735.1380
# 1              DRC01        5.920  ...  Supermarket Type2           443.4228
# 2              FDN15       17.500  ...  Supermarket Type1          2097.2700
# 3              FDX07       19.200  ...      Grocery Store           732.3800
# 4              NCD19        8.930  ...  Supermarket Type1           994.7052
# ...              ...          ...  ...                ...                ...
# 8518           FDF22        6.865  ...  Supermarket Type1          2778.3834
# 8519           FDS36        8.380  ...  Supermarket Type1           549.2850
# 8520           NCJ29       10.600  ...  Supermarket Type1          1193.1136
# 8521           FDN46        7.210  ...  Supermarket Type2          1845.5976
# 8522           DRG01       14.800  ...  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
plt.figure(figsize=(10,4))
sns.boxplot(data=df, x='Item_Weight')

# %%
fig, ax = plt.subplots(figsize=(10,4))

# %%
plt.rcParams['figure.figsize'] = (10,4)

# %%
sns.boxplot(data=df, x='Item_Weight')

# %%
sns.set_context('talk')
sns.boxplot(data=df, x='Item_Weight')

# %%
color

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
fat_content = df['Item_Fat_Content']
fat_content
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 8523, dtype: object

# %%
df['Item_Weight'].fillna( df['Item_Weight'].median(),inplace=True)
df['Outlet_Size'].fillna( 'MISSING',inplace=True)
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
s

# %%
plt.hist(df['Item_Weight'],bins='auto');

# %%
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace({'LF':'Low Fat','low fat':'Low Fat','reg':'Regular'})
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
plt.bar(df['Item_Fat_Content'].value_counts().index,df['Item_Fat_Content'].value_counts())
# Out:
# <BarContainer object of 5 artists>

# %%
fig, ax = plt.subplots()
ax.bar(df['Item_Fat_Content'].value_counts().index,df['Item_Fat_Content'].value_counts())
# Out:
# <BarContainer object of 5 artists>

# %%
fig, axes = plt.subplots(nrows=2)
axes[1].bar(df['Item_Fat_Content'].value_counts().index,df['Item_Fat_Content'].value_counts())
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### Dummy-Encoding of Categorical Variables

# %%
## Convert Item Fat Content string column to multiple Ohe-Hot-Encoded / Dummy-Encoded columns
df_dummies = pd.get_dummies( df['Item_Fat_Content'])
df_dummies['Item_Weight'] = df['Item_Weight'].copy()
df_dummies
# Out:
#       Low Fat  Regular  Item_Weight
# 0           1        0        9.300
# 1           0        1        5.920
# 2           1        0       17.500
# 3           0        1       19.200
# 4           1        0        8.930
# ...       ...      ...          ...
# 8518        1        0        6.865
# 8519        0        1        8.380
# 8520        1        0       10.600
# 8521        0        1        7.210
# 8522        1        0       14.800
#
# [8523 rows x 3 columns]

# %%
df_dummies.corr()
# Out:
#               Low Fat   Regular  Item_Weight
# Low Fat      1.000000 -1.000000     0.021092
# Regular     -1.000000  1.000000    -0.021092
# Item_Weight  0.021092 -0.021092     1.000000

# %%
sns.heatmap(df_dummies.corr(),annot=True,square=True,cmap='RdYlGn')

# %%
## Convert Item Fat Content string column to multiple Ohe-Hot-Encoded / Dummy-Encoded columns
df_dummies = pd.get_dummies( df['Item_Fat_Content'])
df_dummies
# Out:
#       Low Fat  Regular
# 0           1        0
# 1           0        1
# 2           1        0
# 3           0        1
# 4           1        0
# ...       ...      ...
# 8518        1        0
# 8519        0        1
# 8520        1        0
# 8521        0        1
# 8522        1        0
#
# [8523 rows x 2 columns]

# %%
df_dummies.corrwith(df['Item_Weight'])
# Out:
# Low Fat    0.021092
# Regular   -0.021092
# dtype: float64

# %%
df.corr()
# Out:
#                            Item_Weight  ...  Item_Outlet_Sales
# Item_Weight                   1.000000  ...           0.009693
# Item_Visibility              -0.014168  ...          -0.128625
# Item_MRP                      0.024951  ...           0.567574
# Outlet_Establishment_Year     0.007739  ...          -0.049135
# Item_Outlet_Sales             0.009693  ...           1.000000
#
# [5 rows x 5 columns]

# %%
sns.regplot(data=df, x='Item_Weight',y='Item_Outlet_Sales')

# %% [markdown]
# ### Student Question/Comment Regarding Item Weight Affecting Sales

# %%
## what if we dropped missisng weights?
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSsu3nnH_Ppm4Ao9XUqVlUZPfTx8bGv5gNbfSavqMhPhIWp4NwaEZk3W8FgDEhEJbg12sRU_FG5EBAb/pub?output=csv')
df.dropna(subset=['Item_Weight'],inplace=True)
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.corr()
# Out:
#                            Item_Weight  ...  Item_Outlet_Sales
# Item_Weight                   1.000000  ...           0.014123
# Item_Visibility              -0.014048  ...          -0.085334
# Item_MRP                      0.027141  ...           0.620961
# Outlet_Establishment_Year    -0.011588  ...           0.012212
# Item_Outlet_Sales             0.014123  ...           1.000000
#
# [5 rows x 5 columns]

# %%
sns.regplot(data=df, x='Item_Weight',y='Item_Outlet_Sales',line_kws={'color':'black',
                                                                     'ls':':'})

# %%
sns.heatmap(df.corrwith(df['Item_Outlet_Sales']).to_frame(),annot=True,cmap='RdYlGn')

# %% [markdown]
# ## Cats Dogs

# %%
url="https://docs.google.com/spreadsheets/d/e/2PACX-1vTXqVI5_p-kjmdG6Ww9mxHJfB_rM3VlLIbIk6HGCWgy1b0Fy3i9AscZm2JHU9re5Q/pub?output=xlsx"
df = pd.read_excel(url)
df
# Out:
#                 Location  ...  Cat Population
# 0                Alabama  ...          1252.0
# 1                Arizona  ...          1438.0
# 2               Arkansas  ...           810.0
# 3             California  ...          7118.0
# 4               Colorado  ...          1191.0
# 5            Connecticut  ...           796.0
# 6               Delaware  ...           187.0
# 7   District of Columbia  ...            63.0
# 8                Florida  ...          4375.0
# 9                Georgia  ...          2162.0
# 10                 Idaho  ...           393.0
# 11              Illinois  ...          2453.0
# 12               Indiana  ...          1912.0
# 13                  Iowa  ...           805.0
# 14                Kansas  ...           731.0
# 15              Kentucky  ...          1349.0
# 16             Louisiana  ...           877.0
# 17                 Maine  ...           498.0
# 18              Maryland  ...          1677.0
# ...

# %%
# sns.boxplot(data=df,y=[['Mean Number of Dogs per household'], color = 'orange')
# sns.boxplot(y=df['Mean Number of Cats']);

# %%
df.boxplot(column=['Mean Number of Cats','Mean Number of Dogs per household'])
