# %% [markdown]
# # **Histogram & Boxplots Exercise (Core)**
# **Student**: Michael McCann <br>
# **Date**: 08 FEB 2022

# %%
## Load Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Import libraries
import numpy as np
import pandas as pd     
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Load Data: 
filepath = "/content/drive/MyDrive/Data/catsvdogs.xlsx"
catdog_df = pd.read_excel(filepath)

# %%
display(catdog_df.head())
catdog_df.info()
# Out:
#      Location  ...  Cat Population
# 0     Alabama  ...            1252
# 1     Arizona  ...            1438
# 2    Arkansas  ...             810
# 3  California  ...            7118
# 4    Colorado  ...            1191
#
# [5 rows x 12 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 12 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Location                            49 non-null     object
#  1   Number of Households (in 1000)      49 non-null     int64
#  2   Percentage of households with pets  49 non-null     float64
#  3   Number of Pet Households (in 1000)  49 non-null     int64
#  4   Percentage of Dog Owners            49 non-null     float64
#  5   Dog Owning Households (1000s)       49 non-null     int64
#  6   Mean Number of Dogs per household   49 non-null     float64
# ...

# %% [markdown]
# # (1) Plot a histogram of the Percentage of Dog Owners.

# %%
plt.style.use('seaborn')
#catdog_df['Percentage of Dog Owners'].hist(bins = 10, range = (0, 50), label = "Dog", color = 'lightblue', edgecolor = 'black', alpha = 0.8);
catdog_df['Percentage of Dog Owners'].hist(label = "Dog", color = 'lightblue', edgecolor = 'black', alpha = 0.8);
plt.ticklabel_format(useOffset=False, style='plain')
plt.ylabel('Count')
plt.xlabel('Percentage of Dog Owners');
plt.xticks(np.arange(10, 50, step= 5.0))
plt.legend(loc="upper right");

#price_filter = kc_df.loc[:, 'price'] <= 3000000
#kc_df.loc[price_filter, 'price'].hist(bins = 30, edgecolor='black')
#plt.xticks(rotation = 45)
#plt.ticklabel_format(useOffset=False, style='plain')

# %% [markdown]
# # (2) Plot a histogram of the Percentage of Cat Owners.

# %%
plt.style.use('seaborn')
#catdog_df['Percentage of Dog Owners'].hist(bins = 10, range = (0, 50), label = "Dog", color = 'lightblue', edgecolor = 'black', alpha = 0.8);
catdog_df['Percentage of Cat Owners'].hist(label = "Cat", color = 'Orange', edgecolor = 'black', alpha = 0.8);
plt.ticklabel_format(useOffset=False, style='plain')
plt.ylabel('Count')
plt.xlabel('Percentage of Cat Owners');
plt.xticks(np.arange(10, 50, step= 5.0))
plt.legend(loc="upper right");

# %% [markdown]
# # (3a) What can we see by comparing these two histograms? What information does this tell us?
#
# There seems to be a large cluster of cat owners per state in the 25 to 35% range whereas percentage of dog ownership seems to be a little more evenly distributed between 30 and 45%.

# %% [markdown]
# # (3b) Optional/Bonus: plot these two histograms on the same plot. An example of what this could look like is given below:

# %%
#plt.style.use('seaborn')
#catdog_df['Percentage of Dog Owners'].hist(bins = 10, range = (0, 50), label = "Dog", color = 'lightblue', edgecolor = 'black', alpha = 0.8);
catdog_df['Percentage of Dog Owners'].hist(bins = 8, range = (10, 50), label = "Dog", edgecolor = 'black', alpha = 0.7);
catdog_df['Percentage of Cat Owners'].hist(bins = 8, range = (10, 50), label = "Cat", color = 'Orange', edgecolor = 'black', alpha = .7);
plt.ticklabel_format(useOffset=False, style='plain')
plt.ylabel('Count')
plt.xlabel('Percentage of Animal Owners');
plt.xticks(np.arange(10, 51, step= 5))
plt.yticks(np.arange(2, 19, step= 2))
plt.legend(loc="upper right");

# %% [markdown]
# # (4) Create two boxplots on the same plot: one of the mean number of cats per household and the other of the mean number of dogs. An example of what this might look like is given below:

# %%
meandogs = catdog_df['Mean Number of Dogs per household']
meancats= catdog_df['Mean Number of Cats']
plt.boxplot([meandogs, meancats], 
            notch = True, 
            widths = .7,
            #boxprops = dict(linestyle='--', linewidth=2, color='Black', facecolor = 'blue', alpha = .4),
            labels=['Dogs', 'Cats']);

# %%
meandogs = catdog_df['Mean Number of Dogs per household']
meancats= catdog_df['Mean Number of Cats']

fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (8,5))
boxplots = axes.boxplot([meancats, meandogs],
           notch = True,
           labels=['cats', 'dogs'],
           widths = .7,
           patch_artist=True,
           medianprops = dict(linestyle='-', linewidth=2, color='Yellow'),
           boxprops = dict(linestyle='--', linewidth=2, color='Black', facecolor = 'blue', alpha = .4)
          );
# The more you understand any library, the more you can do
boxplot1 = boxplots['boxes'][0]
boxplot1.set_facecolor('orange')
#plt.xlabel('Number of Pets', fontsize = 20);
plt.ylabel('Mean Number of Animals per State', fontsize = 20);
plt.xticks(fontsize = 16);
plt.yticks(fontsize = 16);

# %% [markdown]
# # (5) What can we see by comparing these two boxplots? What information does this tell us?
#
# Boxplot suggests that people are more likely to own more cats per household than dogs. 75% (the bottom 3 quartiles) of dog ownership falls below the bottom of the cats boxplot.
